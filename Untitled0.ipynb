# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# %cd Colab Notebooks/beautiful2
# Out:
# /content/drive/MyDrive/Colab Notebooks/beautiful2

# %%
# !pip -q install timm==0.5.4
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 55.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 66.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 63.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.1 MB/s eta 0:00:00
# ...

# %%
# !ls
# Out:
#  AVA.txt		 efficientnet_train.py	 make_graph.py	 trainer.py
#  convert_annotation.py	 images			 __pycache__	'Untitled0.ipynb のコピー のコピー'

# %%
# !python3 convert_annotation.py --annotation_path ./AVA.txt --image_dir ./images
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# WARNING:absl:./images/929914.jpg is not readable
# WARNING:absl:./images/930390.jpg is not readable
# WARNING:absl:./images/930735.jpg is not readable
# WARNING:absl:./images/930476.jpg is not readable
# WARNING:absl:./images/930756.jpg is not readable
# WARNING:absl:./images/930021.jpg is not readable
# WARNING:absl:./images/930379.jpg is not readable
# WARNING:absl:./images/930770.jpg is not readable
# WARNING:absl:./images/930542.jpg is not readable
# WARNING:absl:./images/930236.jpg is not readable
# WARNING:absl:./images/930698.jpg is not readable
# WARNING:absl:./images/930761.jpg is not readable
# WARNING:absl:./images/930703.jpg is not readable
# WARNING:absl:./images/930809.jpg is not readable
# WARNING:absl:./images/930732.jpg is not readable
# WARNING:absl:./images/929777.jpg is not readable
# WARNING:absl:./images/929936.jpg is not readable
# WARNING:absl:./images/930531.jpg is not readable
# ...

# %%
# !python3 beautiful_model.py
# Out:
#   0% 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1511: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# 100% 5/5 [00:02<00:00,  2.34it/s]
# 100% 1/1 [00:00<00:00,  7.64it/s]
# epoch: 1,                train loss: 3.698351240158081,                test loss: 4.104522705078125
# 100% 5/5 [00:00<00:00, 11.62it/s]
# 100% 1/1 [00:00<00:00, 36.36it/s]
# epoch: 2,                train loss: 3.3248135566711428,                test loss: 3.7635467052459717
# 100% 5/5 [00:00<00:00, 11.53it/s]
# 100% 1/1 [00:00<00:00, 37.97it/s]
# epoch: 3,                train loss: 3.337204933166504,                test loss: 3.9022011756896973
